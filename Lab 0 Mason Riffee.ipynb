# %%
import pandas as pd
import numpy as np

# %%
our_data2 = pd.read_csv('DS6021_F26_Class Data.csv')

# %%
our_data
# Out:
#                           date  \
# 0    2026/08/25 8:20:42 AM AST
# 1    2026/08/25 9:35:50 AM AST
# 2    2026/08/25 1:43:22 PM AST
# 3    2026/08/25 3:11:38 PM AST
# 4    2026/08/25 3:26:11 PM AST
# ..                         ...
# 81  2026/08/26 11:42:56 AM AST
# 82  2026/08/26 11:44:34 AM AST
# 83  2026/08/26 11:48:22 AM AST
# 84  2026/08/26 11:52:24 AM AST
# 85  2026/08/26 12:16:47 PM AST
#
#                                                major    phone  \
# 0                                         Psychology   iPhone
# 1                                         Statistics   iPhone
# 2         Economics-Business and Applied Mathematics   iPhone
# 3   Data Science (concentration in Computer Science)   iPhone
# 4                                   Math and Physics   iPhone
# ..                                               ...      ...
# 81                        Bioinformatics and Biology   iPhone
# 82                                  Computer Science   iPhone
# ...

# %%
our_data.sleep_hours.unique()
# Out:
# <StringArray>
# ['8', '7', '6.5', '9', '5', '8.5', '4.5', '7.5', '6', '5.5']
# Length: 10, dtype: str

# %%
our_data.groupby('fav_tv_sport').size()
# Out:
# fav_tv_sport
# American Football                                     1
# Baseball                                              5
# Baseball/Football                                     1
# Basketball                                            9
# Basketball                                            2
# College Basketball                                    2
# College Football                                      2
# College Hoops                                         1
# College Softball                                      1
# College football                                      1
# College football                                      1
# Cricket                                               2
# Does the Superbowl count? That's all I watch.         1
# F1 motorsport                                         1
# Figure Skating                                        1
# Football                                             18
# ...

# %%
our_data.iloc[[74],4] = '8'

# %% [markdown]
# **Notable stats:**
# Most people have iphones
# About 2/3's of students are fresh out of undergrad and the remaining 1/6 and 1/6 have 1-3 or 3-6 years of professional experience.
# The average reported git and python proficiencies are low (2 and 3, respectively).
# Most students get 7 hours of sleep +- 1 hour. Some outliers get very little. Nobody gets more than 9.
# About 2/3's of people have used SQL.
# Fall is the fav season of 50% of students. Spring 25%, Summer 20%, Winter 5%.
# Football seems to be the top sport. Not gonna bother cleaning that big mess!
